# %%
start = 50
dictionnary = []

# %%
with open("input.txt", "r") as puzzle_input:
    for line in puzzle_input:
        dictionnary.append([line[0], line[1:].strip()])

# %%
dictionnary
# Out:
# [['L', '68'],
#  ['L', '30'],
#  ['R', '48'],
#  ['L', '5'],
#  ['R', '60'],
#  ['L', '55'],
#  ['L', '1'],
#  ['L', '99'],
#  ['R', '14'],
#  ['L', '82']]

# %%
for line in dictionnary:
    print(line)
# Out:
# ['L', '68']
# ['L', '30']
# ['R', '48']
# ['L', '5']
# ['R', '60']
# ['L', '55']
# ['L', '1']
# ['L', '99']
# ['R', '14']
# ['L', '82']
